# %% [raw]
# ---
# title: " "
# ---

# %% [markdown]
# <h1 style="text-align: center;">
#
# Previous Research Teaching Videos
#
# </h1>
#
# <h1 style="text-align: center;">
#
# Statistics for clinical researchers
#
# </h1>
#
# <h2 style="text-align: center;">
#
# Professor Jeremy Dawson
#
# </h2>
#
# ##
#
#
# ```{html}
#
# <div class="iframe-container">
#
#   <div class="responsive-iframe">
#
# <iframe src="https://drive.google.com/file/d/1VRGsvJh-lLNOpe0EW277SiL9eVtnO-0f/preview" allow="autoplay">
#
# </iframe>
#
# </div>
#
# </div>
#
# <h1 style="text-align: center;">
#
# Patient and Public Involvement in Research
#
# </h1>
#
# <h2 style="text-align: center;">
#
# Professor Bob Phillips
#
# </h2>
#
# <div class="iframe-container">
#
#   <div class="responsive-iframe">
#
# </iframe>
#
# <iframe src="https://www.youtube.com/embed/2Nf6fhkOoQg?si=8verGBhp8VybGqA-" allow="autoplay">
#
# </iframe>
#
# </div>
#
# </div>
#
# <h1 style="text-align: center;">
#
# Introduction to the COMET study in neonatology
#
#
# </h1>
#
# <h2 style="text-align: center;">
#
# Dr Kathryn Johnson
#
# </h2>
#
#
# <div class="iframe-container">
#
#   <div class="responsive-iframe">
#
# </iframe>
#
# <iframe src="https://drive.google.com/file/d/1y5yTe-WDVuLhSXj5ZmTly65chIbTwNNr/preview" allow="autoplay">
#
# </iframe>
#
# </div>
#
# </div>
#
# <p style="text-align: center;">
#
#
# <br /> <br />
#
# </p>
#
# </iframe>
#
#
#
#
# </iframe>
#
# <h1 style="text-align: center;">
#
# Building A Journal Club
#
# </h1>
#
# <h2 style="text-align: center;">
#
# Dr Sean O'Riordan
#
# </h2>
#
#
#
#
# <div class="iframe-container">
#
#   <div class="responsive-iframe">
#
# </iframe>
#
# <iframe src="https://drive.google.com/file/d/1WYapG6KjHUu1ABQn2Zz9GJcUiPmaIh73/preview" allow="autoplay">
#
# </iframe>
#
# </div>
#
# </div>
#
#
#
# <!-- this is old code that used to embed from youtube -->
#
# <!-- <iframe width="300" height="120" src="https://www.youtube.com/embed/wWCHrONFfYQ?si=2z2IJg_2dNQfUKwK" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe> -->
#
# <!-- <br /> -->
#
# <!-- Or you can use a link for videos instead:<br /> -->
#
# <!-- Watch the Professor Bob Phillips, Patient and Public Involvement in Research -->
# ```
